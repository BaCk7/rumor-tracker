# %%
import codecs
import CMUTweetTaggerWindows
import os

class TweetParser(object):
    def __init__ (self, tags_to_keep=[]):
        self.tags_to_keep = tags_to_keep
        self.tags_meaning = {"N":"common noun","O":"pronoun (personal/WH; not possessive)","^":"proper noun","S":"nominal + possessive(lady's)","Z":"proper noun + possessive (Palin's, Alaska's)","V":"verb incl. copula, auxiliaries","A":"adjective","R":"adverb","!":"interjection","D":"determiner","P":"pre- or postposition, or subordinating conjunction","&":"coordinating conjunction","T":"verb particle","X":"existential _there_, predeterminers","#":"hashtag (indicates topic/category for tweet)","@":"at-mention (indicates another user as a recipient of a tweet)","~":"discourse marker, indications of continuation of a message across multiple tweets","U":"URL or email address","E":"emoticon","$":"numeral",",":"punctuation","G":"other abbreviations, foreign words, possessive endings, symbols, garbage","L":"nominal + verbal (e.g. _i'm_), verbal + nominal (_let's_, _lemme_)","M":"proper noun + verbal","Y":" 'X' + verbal"}
        #self.tags_meaning = ""
    
    @property
    def tags_to_keep(self):
        return self.__tags_to_keep

    @tags_to_keep.setter
    def tags_to_keep(self, tags_to_keep):
        self.__tags_to_keep= tags_to_keep
        
    @property
    def tags_meaning(self):
        return self.__tags_meaning
    
    @tags_meaning.setter
    def tags_meaning(self, tags_meaning):
        self.__tags_meaning= tags_meaning
        
    
    def split_result(self,line):
        line = line.strip()  # remove '\n'
        if len(line) > 0:
            parts = line.split('\t')
            tokens = parts[0].split(" ")
            tags = parts[1].split(" ")
            confidence = parts[2].split(" ")
            res=[]
            for i in range(len(tokens)):
                res.append((tokens[i],tags[i],confidence[i]))
            return res

    def parse_tags_from_file(self,filename):
        import codecs
        with open (filename,"r") as f:
            tags = []
            for line in f:
                result = self.split_result(line)
                if self.tags_to_keep: #ho specificato una lista di tag: devo filtrare, tengo solo se tag è in tags_to_keep
                    result= [ tripletta for tripletta in result if tripletta[1] in self.tags_to_keep ]
                tags.append(result)
        return tags

    def tokenize_tweets(self,tweets):
        file_name = "temp-file.txt"
        o = codecs.open(file_name,'w','utf-8')
        texts = []
        for tweet in tweets:
            txt = tweet['text']
            txt = txt.replace('\n', ' ')
            texts.append(txt)
        message = "\n".join(texts)
        o.write(message)
        o.close()
        filename = CMUTweetTaggerWindows.runFile(file_name)
        tagged = self.parse_tags_from_file(filename)
        os.remove(file_name)
        os.remove(filename)
        return tagged
    
    def tokenize_tweets_from_file(self,file_name):
        filename = CMUTweetTaggerWindows.runFile(file_name)
        tagged = self.parse_tags_from_file(filename)
        os.remove(filename)
        return tagged

# %%
import pymongo
import codecs

client=pymongo.MongoClient()#senza parametri si connette a localhost.

db=client['inforet']#prendo il db, se non c'è lo crea

col = db['rumors_raw']
#with open ("rumors.txt", "a") as f:

file_name = "rumors.txt"
o = codecs.open(file_name,'w','utf-8')

tweets = []
for record in col.find({},{'id','rumor','text'} ):
    tweets.append(record)

tags_to_keep = [ 'N','^','S','Z','A','#','$']

#parser = TweetParser(tags_to_keep)
parser = TweetParser()

# %%
parser.tokenize_tweets_from_file("examples/example_tweets.txt")

parser.tags_meaning

parser.tags_to_keep = tags_to_keep

parser.tags_to_keep

parser.tokenize_tweets(tweets)
# Out:
# [[('Bolivian', '^', '0,9677'),
#   ('news', 'N', '0,8951'),
#   ('stills', 'N', '0,9608'),
#   ('pics', 'N', '0,9922'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9988'),
#   ('disaster', 'N', '0,9832')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9990'),
#   ('jet', 'N', '0,9638'),
#   ('crash', 'N', '0,8447'),
#   ('Search', 'N', '0,8679'),
#   ('teams', 'N', '0,9963'),
#   ('black', 'A', '0,9503'),
#   ('box', 'N', '0,9922'),
#   ('signals', 'N', '0,5163')],
#  [('News', 'N', '0,5745'),
#   ('Outlets', 'N', '0,9900'),
#   ('Shocking', 'A', '0,9778'),
#   ('Air', '^', '0,7680'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7106'),
#   ('Pictures', 'N', '0,9732'),
#   ('Stills', 'N', '0,6595')],
#  [('TV', 'N', '0,8645'),
#   ('station', 'N', '0,9983'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9992'),
#   ('hoax', 'N', '0,9303'),
#   ('pic', 'N', '0,9547')],
#  [('UPDATE', 'N', '0,9448'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('#Air', '#', '0,8290'),
#   ('France', '^', '0,9917'),
#   ('Debris', 'N', '0,8583'),
#   ('passenger', 'N', '0,8446'),
#   ('bags', 'N', '0,9893'),
#   ('dramatic', 'A', '0,9908'),
#   ('picture', 'N', '0,9976'),
#   ('Brazil', '^', '0,9971')],
#  [('truth', 'N', '0,9053'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9987'),
#   ('flight', 'N', '0,9704'),
#   ('pics', 'N', '0,9888')],
#  [('Bolivian', '^', '0,8764'),
#   ('TV', 'N', '0,7130'),
#   ('airs', 'N', '0,6581'),
#   ('photos', 'N', '0,9876'),
#   ('doomed', 'A', '0,6180'),
#   ('Air', 'N', '0,6052'),
#   ('France', '^', '0,9119'),
#   ('flight', 'N', '0,9863'),
#   ('#lost', '#', '0,7462'),
#   ('#fail', '#', '0,8589'),
#   ('ATTN', 'N', '0,6236')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9991'),
#   ('Photo', 'N', '0,6757'),
#   ('Hoax', 'N', '0,9570')],
#  [('Epic', '^', '0,4009'),
#   ('fail', 'N', '0,6239'),
#   ('BNR', '^', '0,9548'),
#   ('Newsradio', '^', '0,9926'),
#   ('Netherlands', '^', '0,9839'),
#   ('pictures', 'N', '0,8593'),
#   ('Air', '^', '0,9011'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8062')],
#  [('scary', 'A', '0,9985'),
#   ('2', '$', '0,8741'),
#   ('photos', 'N', '0,9964'),
#   ('Collision', 'N', '0,7634'),
#   ('Death', 'N', '0,9640'),
#   ('AIR', '^', '0,4204'),
#   ('FRANCE', '^', '0,9989'),
#   ('FLIGHT', 'N', '0,9726')],
#  [('AIRFRANCE', '^', '0,9042'),
#   ('CRASH', 'N', '0,7899'),
#   ('2', '$', '0,8697'),
#   ('photos', 'N', '0,9964'),
#   ('Collision', 'N', '0,7634'),
#   ('Death', 'N', '0,7083'),
#   ('June', '^', '0,9315'),
#   ('1st', 'A', '0,3834'),
#   ('world', 'N', '0,9613'),
#   ('disappearance', 'N', '0,9983'),
#   ('Air', 'N', '0,7244')],
#  [('UPDATE', 'N', '0,9036'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Heart', 'N', '0,8547'),
#   ('Air', '^', '0,9219'),
#   ('France', '^', '0,9989'),
#   ('Crash', 'N', '0,7631'),
#   ('Photos', 'N', '0,9944'),
#   ('On-Board', 'A', '0,7581'),
#   ('Pictures', 'N', '0,9986'),
#   ('flight', 'N', '0,9663'),
#   ('477', '$', '0,9863'),
#   ('Disaster', 'N', '0,9795'),
#   ('alleged', 'A', '0,7570'),
#   ('#airfrance', '#', '0,7157'),
#   ('#af477', '#', '0,9886')],
#  [('Rare', 'A', '0,9769'),
#   ('terrifying', 'A', '0,6972'),
#   ('photos', 'N', '0,9989'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,9032')],
#  [('scary', 'A', '0,9985'),
#   ('2', '$', '0,8741'),
#   ('photos', 'N', '0,9964'),
#   ('Collision', 'N', '0,7634'),
#   ('Death', 'N', '0,9640'),
#   ('AIR', '^', '0,4204'),
#   ('FRANCE', '^', '0,9989'),
#   ('FLIGHT', 'N', '0,9726')],
#  [('Air', '^', '0,5383'),
#   ('France', '^', '0,9988'),
#   ('survivor/car', 'N', '0,7972'),
#   ('crash', 'N', '0,8343'),
#   ('victim', 'N', '0,9941'),
#   ('Final', 'A', '0,7192'),
#   ('Destination', 'N', '0,9985'),
#   ('trending', 'A', '0,4414'),
#   ('topic', 'N', '0,9981')],
#  [('lulz', 'N', '0,4946'),
#   ('day', 'N', '0,9984'),
#   ('Bolivian', '^', '0,9273'),
#   ('TV', 'N', '0,6962'),
#   ('Stills', 'N', '0,9672'),
#   ('Exclusive', 'A', '0,9152'),
#   ('Air', '^', '0,8159'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7918'),
#   ('PhotosNetwork', 'N', '0,2873'),
#   ('executives', 'N', '0,9953')],
#  [('Logo', 'N', '0,8001'),
#   ('Tv', 'N', '0,8948'),
#   ('Bolivian', '^', '0,8855'),
#   ('TV', 'N', '0,7250'),
#   ('photos', 'N', '0,9890'),
#   ('doomed', 'A', '0,6180'),
#   ('Air', 'N', '0,6052'),
#   ('France', '^', '0,9119'),
#   ('flight', 'N', '0,9626'),
#   ('Bolivian', '^', '0,7626'),
#   ('TV', 'N', '0,7250'),
#   ('photos', 'N', '0,9890'),
#   ('doomed', 'A', '0,5886')],
#  [('blog', 'N', '0,9954'),
#   ('actual', 'A', '0,9320'),
#   ('news', 'N', '0,9920'),
#   ('video', 'N', '0,9991'),
#   ('TV', 'N', '0,9666'),
#   ('station', 'N', '0,9977'),
#   ('FAKE', 'A', '0,9889'),
#   ('pictures', 'N', '0,9994'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9990'),
#   ('plane', 'N', '0,9408'),
#   ('crash', 'N', '0,6535')],
#  [('Air', '^', '0,6852'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,9144'),
#   ('2', '$', '0,8743'),
#   ('photos', 'N', '0,9964'),
#   ('Collision', 'N', '0,7634'),
#   ('Death', 'N', '0,9716')],
#  [('Bolivian', '^', '0,9326'),
#   ('TV', 'N', '0,7085'),
#   ('BNR', '^', '0,8980'),
#   ('#AirFranceCrash', '^', '0,5837'),
#   ('-pics', 'N', '0,6360')],
#  [('Suspicions', 'N', '0,9717'),
#   ('Air', '^', '0,8704'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9195'),
#   ('447', '$', '0,9900'),
#   ('Times', 'N', '0,7943'),
#   ('Online', 'A', '0,9200'),
#   ('Blogs', 'N', '0,9620')],
#  [('yesterday', 'N', '0,5050'),
#   ('so-called', 'A', '0,9948'),
#   ('#Air', '#', '0,5634'),
#   ('France', '^', '0,9820'),
#   ('pix', 'N', '0,9420'),
#   ('hoax', 'N', '0,9680'),
#   ('TV', 'N', '0,5430'),
#   ('show', 'N', '0,9816'),
#   ('#Lost', 'N', '0,4565')],
#  [('Search', 'N', '0,8306'),
#   ('Crews', 'N', '0,9924'),
#   ('AirFrance', '^', '0,9473'),
#   ('Kitchen', '^', '0,6313'),
#   ('Intact', 'A', '0,9072'),
#   ('Photos', 'N', '0,9911')],
#  [('Disturbing', 'A', '0,9746'),
#   ('Pics', 'N', '0,9571'),
#   ('board', 'N', '0,9340'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9986'),
#   ('AF477', '^', '0,8885'),
#   ('Plane', '^', '0,9738'),
#   ('#airfrance', '#', '0,9016')],
#  [('Evangeline', '^', '0,9926'),
#   ('Lilly', '^', '0,9997'),
#   ('board', 'N', '0,9435'),
#   ('Air', 'N', '0,6994'),
#   ('France', '^', '0,9031'),
#   ('447', '$', '0,9646'),
#   ('Photos', 'N', '0,9923')],
#  [('Pictures', 'N', '0,9446'),
#   ('Air', '^', '0,7438'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9772'),
#   ('friend', 'N', '0,9960'),
#   ('shots', 'N', '0,9984'),
#   ('final', 'A', '0,9894'),
#   ('moments', 'N', '0,9993'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9971')],
#  [('Epic', 'A', '0,6736'),
#   ('superfail', 'N', '0,8246'),
#   ('van', '^', '0,6225'),
#   ('BNR', '^', '0,9891'),
#   ('nepfoto\xe2\x80\x99s', 'Z', '0,4927'),
#   ('van', '^', '0,9112'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9979'),
#   ('crash', 'N', '0,7685')],
#  [('Augean', '^', '0,7197'),
#   ('Stables', '^', '0,7458'),
#   ('\xc2\xbb', '^', '0,4600'),
#   ('Pictures', '^', '0,5840'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9772'),
#   ('world', 'N', '0,9821'),
#   ('disappearance', 'N', '0,9983'),
#   ('Air', '^', '0,5454'),
#   ('France', '^', '0,9985'),
#   ('aircraft', 'N', '0,9797')],
#  [('2', '$', '0,6580'),
#   ('SHOCKING', 'A', '0,9921'),
#   ('PHOTOS', 'N', '0,9990'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9988'),
#   ('A330', '^', '0,6458'),
#   ('Crash', 'N', '0,6397'),
#   ('Inside', 'N', '0,6582'),
#   ('#airfrance', '#', '0,8803')],
#  [('Photos', 'N', '0,9963'),
#   ('Air', '^', '0,9279'),
#   ('France', '^', '0,9979')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9982'),
#   ('447', '$', '0,9460'),
#   ('Crash', 'N', '0,8666'),
#   ('Theory', 'N', '0,9094'),
#   ('Tail', 'N', '0,9557'),
#   ('photo', 'N', '0,9975'),
#   ('Air', '^', '0,7605'),
#   ('Franc', 'N', '0,6448')],
#  [('Bolivian', '^', '0,9095'),
#   ('Polish', '^', '0,5508'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893'),
#   ('FUNNY', 'A', '0,9991')],
#  [('air', 'N', '0,9292'), ('france', '^', '0,5797')],
#  [('Heboh', '^', '0,4617'),
#   ('Foto2', '^', '0,5721'),
#   ('palsu', '^', '0,6628'),
#   ('kecelakaan', '^', '0,8344'),
#   ('pesawat', '^', '0,9159'),
#   ('Air', '^', '0,9822'),
#   ('France', '^', '0,9989'),
#   ('plus', 'A', '0,3959'),
#   ('Pic', 'N', '0,8974'),
#   ('Beberapa', '^', '0,8147'),
#   ('saat', '^', '0,6644'),
#   ('yang', '^', '0,3688'),
#   ('lalu', '^', '0,5457')],
#  [('UPDATE', 'N', '0,9448'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('photos', 'N', '0,9946'),
#   ('air', 'N', '0,8498'),
#   ('france', '^', '0,7056'),
#   ('447', '$', '0,9788'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('brave', 'A', '0,9925'),
#   ('pho', 'N', '0,9753')],
#  [('Pic', 'N', '0,5466'),
#   ('#2', '$', '0,9046'),
#   ('stomach', 'N', '0,9961'),
#   ('drop', 'N', '0,8404'),
#   ('Rare', 'A', '0,8963'),
#   ('terrifying', 'A', '0,6972'),
#   ('photos', 'N', '0,9989'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8783')],
#  [('photos', 'N', '0,9946'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,8341'),
#   ('photographer', 'N', '0,9995')],
#  [('real', 'A', '0,9805'),
#   ('e-mail', 'N', '0,9857'),
#   ('pics', 'N', '0,9132'),
#   ('Air', '^', '0,5454'),
#   ('France', '^', '0,9988'),
#   ('passenger', 'N', '0,9359'),
#   ('mind', 'N', '0,9753')],
#  [('info', 'N', '0,9204'),
#   ('Final', 'A', '0,7681'),
#   ('Destination', 'N', '0,9992'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('lady', 'N', '0,9690'),
#   ('car', 'N', '0,9978'),
#   ('crash', 'N', '0,8055')],
#  [('Bolivian', '^', '0,9468'),
#   ('fools', '^', '0,7393'),
#   ('Bolivian', '^', '0,9328'),
#   ('tv', 'N', '0,9167'),
#   ('air', 'N', '0,8224'),
#   ('france', '^', '0,6959'),
#   ('last', 'A', '0,9891'),
#   ('moment', 'N', '0,9958'),
#   ('pics', 'N', '0,9620'),
#   ('LOST', 'A', '0,7003')],
#  [('\xce\x92\xcf\x81\xce\xb5\xce\xaf\xcf\x84\xce\xb5', '^', '0,3124'),
#   ('\xcf\x84\xce\xb9\xcf\x82', '^', '0,5740'),
#   ('\xce\xb4\xce\xb9\xce\xb1\xcf\x86\xce\xbf\xcf\x81\xce\xad\xcf\x82',
#    '^',
#    '0,6885'),
#   ('Air', '^', '0,6911'),
#   ('France', '^', '0,9981')],
#  [('French', '^', '0,8360'),
#   ('Navy', '^', '0,9137'),
#   ('first', 'A', '0,6362'),
#   ('signals', 'N', '0,9843'),
#   ('Black', '^', '0,8935'),
#   ('Box', '^', '0,9156'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9460'),
#   ('AF447', 'N', '0,4375')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9982'),
#   ('pictures', 'N', '0,9770'),
#   ('terrifying', 'A', '0,9956'),
#   ('two', '$', '0,9690'),
#   ('weeks', 'N', '0,9871'),
#   ('Real', 'A', '0,8371'),
#   ('fake', 'A', '0,9447')],
#  [('AIR', '^', '0,6636'),
#   ('FRANCE', '^', '0,9987'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,8923'),
#   ('BNR', '^', '0,7756'),
#   ('Newsradio', '^', '0,9965'),
#   ('Netherlands', '^', '0,9993'),
#   ('Bolivian', '^', '0,9625'),
#   ('TV', 'N', '0,7282'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9994'),
#   ('plane', 'N', '0,9056'),
#   ('crash', 'N', '0,7187')],
#  [('slecht', 'N', '0,6941'),
#   ('Epic', 'A', '0,3692'),
#   ('fail', 'N', '0,9748'),
#   ('BNR', '^', '0,9548'),
#   ('Newsradio', '^', '0,9926'),
#   ('Netherlands', '^', '0,9839'),
#   ('exclusive', 'A', '0,9943'),
#   ('photos', 'N', '0,9999'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9986'),
#   ('crash', 'N', '0,8936')],
#  [('Para-Pelo', '^', '0,3252'),
#   ('caballo', '^', '0,5622'),
#   ('Foto', '^', '0,8503'),
#   ('que', '^', '0,6041'),
#   ('tomo', 'N', '0,5795'),
#   ('persona', 'N', '0,9377'),
#   ('air', 'N', '0,8425'),
#   ('france', '^', '0,7267')],
#  [('Bolivian', '^', '0,8764'),
#   ('tv', 'N', '0,7957'),
#   ('channel', 'N', '0,9739'),
#   ('pictures', 'N', '0,9296'),
#   ('tv', 'N', '0,8141'),
#   ('show', 'N', '0,9170'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,6888'),
#   ('photos', 'N', '0,9943'),
#   ('Morons', 'N', '0,8448')],
#  [('Dutch', 'A', '0,7337'),
#   ('TV', 'N', '0,9900'),
#   ('station', 'N', '0,9991'),
#   ('photos', 'N', '0,9981'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9723')],
#  [('Bolivian', '^', '0,8764'),
#   ('TV', 'N', '0,7130'),
#   ('airs', 'N', '0,6581'),
#   ('photos', 'N', '0,9876'),
#   ('doomed', 'A', '0,6180'),
#   ('Air', 'N', '0,6052'),
#   ('France', '^', '0,9119'),
#   ('flight', 'N', '0,9947'),
#   ('Bolivian', '^', '0,8631'),
#   ('television', 'N', '0,7511'),
#   ('station', 'N', '0,9977'),
#   ('phot', 'N', '0,5645')],
#  [('Photos', 'N', '0,9941'),
#   ('Latest', 'A', '0,9936'),
#   ('Clues', 'N', '0,9947'),
#   ('Crash', 'N', '0,9883'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9704')],
#  [('Re', 'N', '0,7745'),
#   ('Air', '^', '0,7414'),
#   ('France', '^', '0,9988'),
#   ('Real', 'A', '0,9697'),
#   ('life', 'N', '0,9935'),
#   ('Final', 'A', '0,8865'),
#   ('Destination', 'N', '0,9997'),
#   ('Quote', 'N', '0,5824'),
#   ('link', 'N', '0,9374'),
#   ('topic', 'N', '0,9468'),
#   ('48936', '$', '0,4860'),
#   ('msg1185604', '$', '0,1660'),
#   ('#msg1185604', '#', '0,4473'),
#   ('date', 'N', '0,9100'),
#   ('12448', '$', '0,7084')],
#  [('two', '$', '0,9710'),
#   ('pictures', 'N', '0,9794'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9992'),
#   ('jet', 'N', '0,9786'),
#   ('crash', 'N', '0,9947')],
#  [('ongebegrijpelijk', '^', '0,3600'),
#   ('Bolivian', '^', '0,9503'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('100%', '$', '0,9481'),
#   ('dematerialise', 'N', '0,6453'),
#   ('#airfrance', '^', '0,8673'),
#   ('Photo', 'N', '0,9364')],
#  [('Pix', 'N', '0,5957'),
#   ('passenger', 'N', '0,9811'),
#   ('Air', '^', '0,8822'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9597'),
#   ('turbulence', 'N', '0,9918')],
#  [('topics', 'N', '0,9414'),
#   ('Air', '^', '0,7310'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9801'),
#   ('morning', 'N', '0,9981'),
#   ('Woman', 'N', '0,8191'),
#   ('Air', '^', '0,9683'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9801'),
#   ('Final', 'A', '0,7330'),
#   ('Destination', 'N', '0,9997')],
#  [('Pic', 'N', '0,5466'),
#   ('#2', '$', '0,9046'),
#   ('stomach', 'N', '0,9961'),
#   ('drop', 'N', '0,8404'),
#   ('Rare', 'A', '0,8963'),
#   ('terrifying', 'A', '0,6972'),
#   ('photos', 'N', '0,9989'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8783')],
#  [('Lamentable', '^', '0,5609'),
#   ('Una', '^', '0,8727'),
#   ('TV', '^', '0,6348'),
#   ('boliviana', '^', '0,4332'),
#   ('informa', '^', '0,5253'),
#   ('del', '^', '0,8643'),
#   ('accidente', '^', '0,7789'),
#   ('Air', '^', '0,7239'),
#   ('France', '^', '0,9982'),
#   ('con', 'N', '0,7010'),
#   ('la', '^', '0,4941'),
#   ('Si', '^', '0,6106'),
#   ('sale', 'N', '0,4627'),
#   ('Kate', '^', '0,9030')],
#  [('comment', 'N', '0,9826'),
#   ('Des', '^', '0,3122'),
#   ('photos', 'N', '0,9260'),
#   ('exclusives', 'N', '0,6460'),
#   ('AirFrance', '^', '0,9276'),
#   ('\xc3\xa0', '^', '0,4565'),
#   ('la', '^', '0,9647'),
#   ('TV', 'N', '0,7916'),
#   ('bolivienne', 'N', '0,6224')],
#  [('AIR', '^', '0,6636'),
#   ('FRANCE', '^', '0,9987'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,8923'),
#   ('BNR', '^', '0,8953'),
#   ('Netherlands', '^', '0,9904'),
#   ('Bolivian', '^', '0,9625'),
#   ('TV', 'N', '0,7282'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9978'),
#   ('plane', 'N', '0,7911'),
#   ('crash', 'N', '0,8865')],
#  [('EPIC', 'N', '0,5540'),
#   ('#FAIL', '#', '0,4771'),
#   ('del', '^', '0,3783'),
#   ('a\xc3\xb1o', '^', '0,4516'),
#   ('Supuestas', '^', '0,5935'),
#   ('fotos', '^', '0,7492'),
#   ('del', '^', '0,8802'),
#   ('accidente', '^', '0,7760'),
#   ('del', '^', '0,8407'),
#   ('avion', '^', '0,9387'),
#   ('AirFrance', '^', '0,9089'),
#   ('son', 'N', '0,5254'),
#   ('LOST', 'A', '0,5655')],
#  [('Photos', 'N', '0,9966'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9984'),
#   ('insiders', 'N', '0,9874'),
#   ('Docstoc', '^', '0,9852')],
#  [('Bolivian', '^', '0,8764'),
#   ('TV', 'N', '0,6642'),
#   ('anchor', 'N', '0,9811'),
#   ('photos', 'N', '0,9938'),
#   ('LOST', 'A', '0,6932'),
#   ('reports', 'N', '0,7309'),
#   ('digital', 'A', '0,8744'),
#   ('camera', 'N', '0,9970'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9987'),
#   ('flight', 'N', '0,9949')],
#  [('Bolivian', '^', '0,9551'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9970'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('bull', 'N', '0,9761'),
#   ('Passenger', '^', '0,5896'),
#   ('Photos', 'N', '0,9848'),
#   ('Air', '^', '0,7574'),
#   ('France', '^', '0,9994'),
#   ('Plane', '^', '0,7514')],
#  [('Air', '^', '0,7384'), ('France', '^', '0,9979'), ('pics', 'N', '0,9652')],
#  [('early', 'A', '0,9514'),
#   ('morning', 'N', '0,9988'),
#   ('wool', 'N', '0,9917'),
#   ('eyes', 'N', '0,9989'),
#   ('shocking', 'A', '0,9952'),
#   ('pictures', 'N', '0,9989'),
#   ('Airfrance', '^', '0,9630'),
#   ('fight', 'N', '0,5689')],
#  [('Passenger', '^', '0,5896'),
#   ('Photos', 'N', '0,9848'),
#   ('Air', '^', '0,7574'),
#   ('France', '^', '0,9993'),
#   ('Plane', '^', '0,7554'),
#   ('horrific', 'A', '0,9973')],
#  [('Agora', '^', '0,7837'),
#   ('que', '^', '0,5848'),
#   ('j\xc3\xa1', '^', '0,7300'),
#   ('Au\xc3\xaa', '^', '0,4696'),
#   ('Air', '^', '0,5149'),
#   ('France', '^', '0,9988'),
#   ('minha', '^', '0,4416'),
#   ('homenagem', '^', '0,5959')],
#  [('Suspicions', 'N', '0,9717'),
#   ('Air', '^', '0,8704'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9095'),
#   ('447', '$', '0,9849')],
#  [('Bolivian', '^', '0,9911'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Air', '^', '0,8044'),
#   ('France', '^', '0,9990'),
#   ('Debris', 'N', '0,9041'),
#   ('8', '$', '0,9934'),
#   ('Photos', 'N', '0,9974')],
#  [('Complete', 'A', '0,7388'),
#   ('galley', 'N', '0,9511'),
#   ('Air', 'N', '0,4985'),
#   ('France', '^', '0,9031'),
#   ('447', '$', '0,9121'),
#   ('sea', 'N', '0,6167'),
#   ('pictures', 'N', '0,9829'),
#   ('odd', 'A', '0,9957')],
#  [('Paris', '^', '0,9912'),
#   ('10', '$', '0,9990'),
#   ('min', 'N', '0,9770'),
#   ('atrasado', 'N', '0,5926'),
#   ('1h30', '$', '0,7417'),
#   ('conex\xc3\xa3o', 'N', '0,5844'),
#   ('Mas', '^', '0,5886'),
#   ('o', '^', '0,4520'),
#   ('lounge', '^', '0,8680'),
#   ('air', 'N', '0,9761'),
#   ('france', '^', '0,7234'),
#   ('\xc3\xa9', '^', '0,3824'),
#   ('aconchegante', '^', '0,6831')],
#  [('#LOST', '^', '0,2834'),
#   ('pix', 'N', '0,5376'),
#   ('Bolivian', '^', '0,9551'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5864'),
#   ('outlets', 'N', '0,9992'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Foto', '^', '0,8135'),
#   ('tomada', '^', '0,7883'),
#   ('el', '^', '0,3645'),
#   ('mom\xc3\xa9nto', '^', '0,7916'),
#   ('del', '^', '0,8463'),
#   ('accidente', '^', '0,6785'),
#   ('dentro', '^', '0,7158'),
#   ('del', '^', '0,8160'),
#   ('avi\xc3\xb3n', '^', '0,9010'),
#   ('Air', '^', '0,7239'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9695'),
#   ('sini\xc3\xa9strado', 'N', '0,2243')],
#  [("Foto\\\\\\'s", 'Z', '0,8877'),
#   ('van', '^', '0,9787'),
#   ('Air', '^', '0,7239'),
#   ('France-crash', '^', '0,9901'),
#   ('TwitPic', '^', '0,4051')],
#  [('photo', 'N', '0,9958'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9987'),
#   ('flight', 'N', '0,9698'),
#   ('one', '$', '0,9701'),
#   ('passengers', 'N', '0,9990'),
#   ('plane', 'N', '0,9751')],
#  [('B777', '^', '0,7908'),
#   ('Freighter', '^', '0,9661'),
#   ('Air', '^', '0,9806'),
#   ('France', '^', '0,9990'),
#   ('Cargo', '^', '0,9203'),
#   ('Flickr', '^', '0,9937'),
#   ('Photo', 'N', '0,8967'),
#   ('B777', '^', '0,8563'),
#   ('Freighter', '^', '0,9656'),
#   ('Air', '^', '0,9756'),
#   ('France', '^', '0,9990'),
#   ('Cargo', '^', '0,9184'),
#   ('curi', '^', '0,7054')],
#  [('UPDATE', 'N', '0,9036'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('#Air', '#', '0,8873'),
#   ('France', '^', '0,9823'),
#   ('photos', 'N', '0,9887'),
#   ('empty', 'A', '0,9262'),
#   ('water', 'N', '0,9966'),
#   ('bottles', 'N', '0,9901'),
#   ('personal', 'A', '0,9816'),
#   ('belongings', 'N', '0,9979'),
#   ('bits', 'N', '0,9770'),
#   ('pieces', 'N', '0,9868'),
#   ('debris', 'N', '0,9768')],
#  [('photos', 'N', '0,9911'),
#   ('AirFrance', '^', '0,9640'),
#   ('447', '$', '0,9769'),
#   ('tail', 'N', '0,9966'),
#   ('loss', 'N', '0,9888')],
#  [('AIR', '^', '0,5484'),
#   ('FRANCE', '^', '0,9986'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,9199'),
#   ('BNR', '^', '0,9157'),
#   ('Newsradio', '^', '0,9926'),
#   ('Netherlands', '^', '0,9905'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9978'),
#   ('plane', 'N', '0,7911'),
#   ('crash', 'N', '0,8525')],
#  [('swine', 'N', '0,9362'),
#   ('flu', 'N', '0,8934'),
#   ('h1n1', 'N', '0,5509'),
#   ('woman', 'N', '0,9917'),
#   ('air', '^', '0,5227'),
#   ('france', '^', '0,9933'),
#   ('flight', 'N', '0,9280'),
#   ('final', 'A', '0,9782'),
#   ('destination', 'N', '0,9991'),
#   ('iphone', 'N', '0,2966'),
#   ('real', 'A', '0,5826'),
#   ('madrid', 'A', '0,3927'),
#   ('dallas', '^', '0,9667'),
#   ('holocaust', 'N', '0,8984')],
#  [('AirFrance', '^', '0,8738'),
#   ('air', 'N', '0,9778'),
#   ('crash', 'N', '0,7237'),
#   ('pics', 'N', '0,9930'),
#   ('Hoax', '^', '0,5733'),
#   ('real', 'A', '0,8254')],
#  [('photos', 'N', '0,9949'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,7612'),
#   ('photographer', 'N', '0,9991')],
#  [('SCOOP', 'N', '0,9562'),
#   ('photo', 'N', '0,9643'),
#   ('retrouv\xc3\xa9e', 'N', '0,3143'),
#   ('les', '^', '0,6354'),
#   ('d\xc3\xa9bris', '^', '0,7550'),
#   ('Air', '^', '0,7990'),
#   ('France', '^', '0,9981')],
#  [('Bolivian', '^', '0,9528'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9813')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9989'),
#   ('Flight', 'N', '0,9143'),
#   ('447', '$', '0,9879'),
#   ('Mr.', '^', '0,9775'),
#   ('Mann', '^', '0,8985'),
#   ('picture', 'N', '0,9982'),
#   ('retrieved', 'A', '0,8085'),
#   ('tail', 'N', '0,9999'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9195'),
#   ('447', '$', '0,9881'),
#   ('one', '$', '0,9272')],
#  [('EPIC', 'N', '0,6434'),
#   ('#FAIL', '#', '0,5049'),
#   ('del', '^', '0,3088'),
#   ('a\xc3\xb1o', '^', '0,4345'),
#   ('Supuestas', '^', '0,5935'),
#   ('fotos', '^', '0,7492'),
#   ('del', '^', '0,8802'),
#   ('accidente', '^', '0,7760'),
#   ('del', '^', '0,8407'),
#   ('avion', '^', '0,9387'),
#   ('AirFrance', '^', '0,9089'),
#   ('son', 'N', '0,5254'),
#   ('LOST', 'A', '0,4970')],
#  [('Lamentable', '^', '0,8609'),
#   ('Una', '^', '0,8234'),
#   ('TV', '^', '0,6054'),
#   ('boliviana', '^', '0,4332'),
#   ('informa', '^', '0,5253'),
#   ('del', '^', '0,8643'),
#   ('accidente', '^', '0,7789'),
#   ('Air', '^', '0,7239'),
#   ('France', '^', '0,9982'),
#   ('con', 'N', '0,7010'),
#   ('la', '^', '0,4941')],
#  [('Topics', 'N', '0,9415'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9759'),
#   ('Woman', 'N', '0,7382'),
#   ('air', 'N', '0,8078'),
#   ('Final', 'A', '0,9204'),
#   ('Destination', 'N', '0,9997'),
#   ('#medodomundo', '#', '0,9719')],
#  [('photos', 'N', '0,9946'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,6238')],
#  [('#TOTC_Pop', '#', '0,8488'),
#   ('Search', 'N', '0,9747'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9195'),
#   ('447', '$', '0,9900'),
#   ('Photo', 'N', '0,6894'),
#   ('Gallery', 'N', '0,9947')],
#  [('stunning', 'A', '0,9942'),
#   ('pics', 'N', '0,9982'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9993'),
#   ('Plane', '^', '0,6644'),
#   ('crash', 'N', '0,8817')],
#  [('photos', 'N', '0,9946'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,8341'),
#   ('photographer', 'N', '0,9995')],
#  [('Disturbing', 'A', '0,9591'),
#   ('Pics', 'N', '0,9688'),
#   ('screenshots', 'N', '0,8871'),
#   ('tv-show', 'N', '0,9909'),
#   ('genuine', 'A', '0,9915'),
#   ('#airfrance', '#', '0,8924')],
#  [('UPDATE', 'N', '0,9036'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893'),
#   ('embarassing', 'A', '0,5684')],
#  [('Idiots', 'N', '0,9657'),
#   ('BNR', '^', '0,7049'),
#   ('Newsradio', '^', '0,9875'),
#   ('Netherlands', '^', '0,9966'),
#   ('photos', 'N', '0,9934'),
#   ('authentic', 'A', '0,9826'),
#   ('Air', 'N', '0,6950'),
#   ('France', '^', '0,9031'),
#   ('photos', 'N', '0,9937')],
#  [('More', 'A', '0,9551'),
#   ('Air', 'N', '0,6264'),
#   ('France', '^', '0,9169'),
#   ('pic', 'N', '0,9443')],
#  [('anybody', 'N', '0,9304'),
#   ('e-mail', 'N', '0,9961'),
#   ('photo', 'N', '0,9752'),
#   ('shots', 'N', '0,9904'),
#   ('passenger', 'N', '0,9811'),
#   ('air', 'N', '0,9337'),
#   ('France', '^', '0,9079'),
#   ('plane', 'N', '0,9748'),
#   ('real', 'A', '0,9522'),
#   ('shots', 'N', '0,9968')],
#  [('Bolivian', '^', '0,8505'),
#   ('TV', '^', '0,5133'),
#   ('station', 'N', '0,9619'),
#   ('photos', 'N', '0,9877'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8683')],
#  [('Pictures', 'N', '0,8998'),
#   ('death', 'N', '0,9981'),
#   ('Air', '^', '0,8822'),
#   ('France', '^', '0,9985'),
#   ('flight', 'N', '0,9887')],
#  [('3', '$', '0,9667'),
#   ('more', 'A', '0,8863'),
#   ('bodies', 'N', '0,8446'),
#   ('Air', '^', '0,8006'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,9371'),
#   ('photo', 'N', '0,9970'),
#   ('Brazilian', 'A', '0,6234'),
#   ('Air', 'N', '0,9702'),
#   ('Force', 'N', '0,7105'),
#   ('June', '^', '0,9984'),
#   ('8', '$', '0,9959'),
#   ('2009', '$', '0,9585')],
#  [('AIR', '^', '0,5216'),
#   ('FRANCE', '^', '0,9986'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,9199'),
#   ('BNR', '^', '0,9157'),
#   ('Newsradio', '^', '0,9926'),
#   ('Netherlands', '^', '0,9948'),
#   ('Bolivian', '^', '0,9496'),
#   ('TV', 'N', '0,7282'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9978'),
#   ('plane', 'N', '0,8329'),
#   ('crash', 'N', '0,5839')],
#  [('TV', 'N', '0,9018'),
#   ('e', 'N', '0,4363'),
#   ('queda', '^', '0,6155'),
#   ('Air', '^', '0,8949'),
#   ('France', '^', '0,9986'),
#   ('#epicfail', '#', '0,9651')],
#  [('News', 'N', '0,5465'),
#   ('Outlets', 'N', '0,9909'),
#   ('Shocking', 'A', '0,9709'),
#   ('Air', '^', '0,8159'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7106'),
#   ('Pictures', 'N', '0,9732'),
#   ('Stills', 'N', '0,6595'),
#   ('Lost', 'A', '0,4394')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9994'),
#   ('Airbus', '^', '0,9919'),
#   ('A320', '^', '0,5599'),
#   ('Flickr', '^', '0,9937'),
#   ('Photo', 'N', '0,8967')],
#  [('Bolivian', '^', '0,8631'),
#   ('TV', 'N', '0,5297'),
#   ('station', 'N', '0,9977'),
#   ('photos', 'N', '0,9922'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,7460')],
#  [('Popular', 'A', '0,6690'),
#   ('News', 'N', '0,9788'),
#   ('Photos', 'N', '0,9831'),
#   ('Seconds', 'N', '0,9577'),
#   ('Death', 'N', '0,9111'),
#   ('A330', '$', '0,6129'),
#   ('Air', 'N', '0,5016'),
#   ('France', '^', '0,8769')],
#  [('topix', 'N', '0,4704'),
#   ('Final', 'A', '0,9172'),
#   ('Destination', 'N', '0,9997'),
#   ('Woman', 'N', '0,7199'),
#   ('Fatal', 'A', '0,6434'),
#   ('Air', 'N', '0,7071'),
#   ('France', '^', '0,9342'),
#   ('Flight', 'N', '0,9633'),
#   ('Car', 'N', '0,7839'),
#   ('Crash', 'N', '0,6400'),
#   ('Days', 'N', '0,9711')],
#  [('Passenger', '^', '0,6339'),
#   ('Photos', 'N', '0,9848'),
#   ('Air', '^', '0,7574'),
#   ('France', '^', '0,9993'),
#   ('Plane', '^', '0,7554'),
#   ('HOAX', 'N', '0,9281')],
#  [('TV', 'N', '0,8823'),
#   ('channel', 'N', '0,9745'),
#   ('footage', 'N', '0,9803'),
#   ('photos', 'N', '0,9841'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,9487')],
#  [('Photos', 'N', '0,9963'),
#   ('Air', '^', '0,9279'),
#   ('France', '^', '0,9989'),
#   ('passenger', 'N', '0,8643'),
#   ('plane', 'N', '0,8908'),
#   ('FALSE', 'A', '0,9667'),
#   ('crazy', 'A', '0,9996'),
#   ('e-mails', 'N', '0,9842')],
#  [('Air', 'N', '0,6051'),
#   ('France', '^', '0,9174'),
#   ('tem', '^', '0,2790'),
#   ('twitter', '^', '0,9977'),
#   ('Uma', '^', '0,6809'),
#   ('hora', '^', '0,5494'),
#   ('n\xc3\xa3o', '^', '0,5803'),
#   ('propicia', '^', '0,5812'),
#   ('para', '^', '0,5460')],
#  [('Pratos', '^', '0,6289'),
#   ('air', 'N', '0,9839'),
#   ('france', '^', '0,7102')],
#  [('Il', '^', '0,5862'),
#   ('Tg', '^', '0,9138'),
#   ('Boliviano', '^', '0,9592'),
#   ('mostra', '^', '0,7058'),
#   ('le', '^', '0,8762'),
#   ('foto', '^', '0,7826'),
#   ('della', '^', '0,9694'),
#   ('cabina', '^', '0,8630'),
#   ("dell'Airbus", '^', '0,9767'),
#   ('Air', '^', '0,9624'),
#   ('France', '^', '0,9989'),
#   ('che', '^', '0,6936'),
#   ('precipita', '^', '0,7651'),
#   ('volo', 'N', '0,7886'),
#   ('Oceanic', 'N', '0,5358'),
#   ('815', '$', '0,9626'),
#   ('di', 'N', '0,6017'),
#   ('pic', 'N', '0,9411')],
#  [('Bolivian', '^', '0,9449'),
#   ('TV', 'N', '0,6962'),
#   ('LOST', 'A', '0,7898'),
#   ('images', 'N', '0,9961'),
#   ('Air', '^', '0,7780'),
#   ('France', '^', '0,9985'),
#   ('photos', 'N', '0,9973'),
#   ('Pathetic', 'A', '0,9775'),
#   ('Mexican', '^', '0,8161'),
#   ('TV', 'N', '0,8188')],
#  [('photos', 'N', '0,9942'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,7785'),
#   ('photographer', 'N', '0,9993')],
#  [('Bolivian', '^', '0,9088'),
#   ('TV', 'N', '0,6688'),
#   ('exclusive', 'A', '0,9902'),
#   ('pics', 'N', '0,9972'),
#   ('passenger', 'N', '0,7783'),
#   ('doomed', 'A', '0,7772'),
#   ('Air', 'N', '0,6052'),
#   ('France', '^', '0,9119'),
#   ('flight', 'N', '0,9820'),
#   ('stills', 'N', '0,7656')],
#  [('hell', 'N', '0,9948'),
#   ('France', '^', '0,9838'),
#   ('trending', 'A', '0,4414'),
#   ('topic', 'N', '0,9969'),
#   ('cohesive', 'A', '0,9948'),
#   ('reason', 'N', '0,9661'),
#   ('mixture', 'N', '0,9920'),
#   ('tweets', 'N', '0,6312'),
#   ('rugby', 'N', '0,6828'),
#   ('vacations', 'N', '0,9921'),
#   ('air', 'N', '0,8124'),
#   ('france', '^', '0,6918'),
#   ('other', 'A', '0,9920'),
#   ('randoms', 'N', '0,9640')],
#  [('FAIL', 'N', '0,4996'),
#   ('EPIC', 'N', '0,6434'),
#   ('#FAIL', '#', '0,5049'),
#   ('del', '^', '0,3088'),
#   ('a\xc3\xb1o', '^', '0,4345'),
#   ('Supuestas', '^', '0,5935'),
#   ('fotos', '^', '0,7492'),
#   ('del', '^', '0,8802'),
#   ('accidente', '^', '0,7760'),
#   ('del', '^', '0,8407'),
#   ('avion', '^', '0,9387'),
#   ('AirFrance', '^', '0,9089'),
#   ('son', 'N', '0,5254'),
#   ('LOST', 'A', '0,5194')],
#  [('media', 'N', '0,5753'),
#   ('fact', 'N', '0,9920'),
#   ('worst', 'A', '0,9869'),
#   ('Bolivian', '^', '0,8731'),
#   ('TV', 'N', '0,5912'),
#   ('aires', 'N', '0,9240'),
#   ('photos', 'N', '0,9937'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9984'),
#   ('crash', 'N', '0,8688')],
#  [('new', 'A', '0,9983'),
#   ('camera', 'N', '0,9823'),
#   ('Easy', 'A', '0,9545'),
#   ('solution', 'N', '0,9998'),
#   ('photos', 'N', '0,9992'),
#   ('37-50', '$', '0,9240'),
#   ('link', 'N', '0,9882')],
#  [('TV', 'N', '0,8645'),
#   ('channel', 'N', '0,9728'),
#   ('footage', 'N', '0,9803'),
#   ('photos', 'N', '0,9841'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,9278')],
#  [('photos', 'N', '0,9948'),
#   ('exclusives', 'N', '0,6759'),
#   ('AirFrance', '^', '0,9276'),
#   ('\xc3\xa0', '^', '0,4565'),
#   ('la', '^', '0,9647'),
#   ('TV', 'N', '0,7916'),
#   ('bolivienne', 'N', '0,4303')],
#  [('Phishing', 'N', '0,8543'),
#   ('vagabundo', 'N', '0,4843'),
#   ('Air', '^', '0,5149'),
#   ('France', '^', '0,9986')],
#  [('tired', 'A', '0,9692'),
#   ('crashes', 'N', '0,7682'),
#   ('AirFrance', '^', '0,9277'),
#   ('Glad', 'A', '0,7627'),
#   ('Terminator', '^', '0,6488'),
#   ('safe', 'A', '0,9333')],
#  [('Pix', 'N', '0,7478'),
#   ('Air', '^', '0,9637'),
#   ('France', '^', '0,9989'),
#   ('crash', 'N', '0,8895'),
#   ('Real', 'A', '0,8533'),
#   ('BS', 'N', '0,6905')],
#  [('et', 'N', '0,5003'),
#   ('tu', 'N', '0,4852'),
#   ('BNR', '^', '0,8285'),
#   ('Epic', 'A', '0,5032'),
#   ('superfail', 'N', '0,8293'),
#   ('van', '^', '0,5708'),
#   ('BNR', '^', '0,9873'),
#   ('nepfoto\xe2\x80\x99s', 'Z', '0,4927'),
#   ('van', '^', '0,9112'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8657')],
#  [('Vindo', '^', '0,5793'),
#   ('pixado', '^', '0,4158'),
#   ('477', '$', '0,9176'),
#   ('HAIR', 'N', '0,9689'),
#   ('France', '^', '0,9601')],
#  [('EPIC', 'N', '0,6434'),
#   ('#FAIL', '#', '0,5049'),
#   ('del', '^', '0,3088'),
#   ('a\xc3\xb1o', '^', '0,4345'),
#   ('Supuestas', '^', '0,5935'),
#   ('fotos', '^', '0,7492'),
#   ('del', '^', '0,8802'),
#   ('accidente', '^', '0,7760'),
#   ('del', '^', '0,8407'),
#   ('avion', '^', '0,9387'),
#   ('AirFrance', '^', '0,9089'),
#   ('son', 'N', '0,5254'),
#   ('LOST', 'A', '0,4970')],
#  [('-Bolivians', '^', '0,8903'),
#   ('LOST', 'A', '0,8523'),
#   ('footage', 'N', '0,9986'),
#   ('France', '^', '0,9965'),
#   ('accident', 'N', '0,9963'),
#   ('photo', 'N', '0,9684'),
#   ('passenger', 'N', '0,9827'),
#   ('ocean', 'N', '0,7381')],
#  [('guy', 'N', '0,9910'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9990'),
#   ('plane', 'N', '0,9190'),
#   ('few', 'A', '0,9187'),
#   ('pics', 'N', '0,9989'),
#   ('cabin', 'N', '0,9978'),
#   ('plane', 'N', '0,9557'),
#   ('pics', 'N', '0,9830'),
#   ('sad', 'A', '0,9988')],
#  [('maleta', '^', '0,3690'),
#   ('esta', '^', '0,6692'),
#   ('caixa', '^', '0,4585'),
#   ('preta', '^', '0,8090'),
#   ('air', 'N', '0,8099'),
#   ('france', '^', '0,6069')],
#  [('Bolivian', '^', '0,8764'),
#   ('TV', 'N', '0,5821'),
#   ('uncovered', 'A', '0,5560'),
#   ('unseen', 'A', '0,9956'),
#   ('photographs', 'N', '0,9999'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9990'),
#   ('plane', 'N', '0,9324'),
#   ('crash', 'N', '0,7158')],
#  [('Bolivian', '^', '0,9326'),
#   ('TV', 'N', '0,7531'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,7207'),
#   ('hoax', 'N', '0,9750'),
#   ('#EPICFAIL', '#', '0,8453')],
#  [('Photo', 'N', '0,8325'),
#   ('Air', '^', '0,9603'),
#   ('France', '^', '0,9995'),
#   ('Airbus', '^', '0,9876'),
#   ('A330', '^', '0,6055')],
#  [('email', 'N', '0,9586'),
#   ('interior-cabin', 'A', '0,8151'),
#   ('pictures', 'N', '0,9996'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8950')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9976'),
#   ('black', 'A', '0,8548'),
#   ('box', 'N', '0,9897'),
#   ('signals', 'N', '0,4887'),
#   ('Reports', 'N', '0,7843'),
#   ('authorities', 'N', '0,5690')],
#  [('FAKE', 'A', '0,9907'),
#   ('PICS', 'N', '0,9582'),
#   ('DUDE', 'N', '0,9714'),
#   ('Plane', '^', '0,4567'),
#   ('NIGHT', 'N', '0,9011'),
#   ('pics', 'N', '0,9519'),
#   ('air', 'N', '0,8498'),
#   ('france', '^', '0,7056'),
#   ('447', '$', '0,9683'),
#   ('crash', 'N', '0,8964')],
#  [('NEWS', 'N', '0,8073'),
#   ('UPDATE', 'N', '0,9873'),
#   ('Two', '$', '0,8896'),
#   ('Photos', 'N', '0,9944'),
#   ('Passenger', 'N', '0,6947'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,8705'),
#   ('seconds', 'N', '0,8268')],
#  [('World', 'N', '0,7121'),
#   ('Air', '^', '0,7414'),
#   ('France', '^', '0,9992'),
#   ('Black', '^', '0,7246'),
#   ('Boxes', '^', '0,6758'),
#   ('French', '^', '0,8594'),
#   ('Newspaper', '^', '0,5695'),
#   ('Navy', '^', '0,8526'),
#   ('Weak', 'A', '0,9991'),
#   ('Si', '^', '0,8573')],
#  [('typical', 'A', '0,9898'),
#   ('functioning', 'N', '0,5827'),
#   ('aircraft', 'N', '0,9886'),
#   ('Air', '^', '0,7691'),
#   ('France', '^', '0,9988'),
#   ('Disaster', 'N', '0,8844')],
#  [('photos', 'N', '0,9946'),
#   ('Air', '^', '0,8595'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9815'),
#   ('tail', 'N', '0,9955'),
#   ('loss', 'N', '0,9978'),
#   ('Brave', 'A', '0,8341'),
#   ('photographer', 'N', '0,9995')],
#  [('Epic', 'A', '0,4023'),
#   ('FAIL', 'N', '0,9383'),
#   ('El', '^', '0,5762'),
#   ('video', 'N', '0,9062'),
#   ('PAT', '^', '0,9958'),
#   ('Noticias', '^', '0,9958'),
#   ('las', '^', '0,2449'),
#   ('fotos', '^', '0,7682'),
#   ('la', '^', '0,6399'),
#   ('tragedia', '^', '0,6103'),
#   ('del', '^', '0,8463'),
#   ('vuelo', '^', '0,6992'),
#   ('447', '$', '0,9316'),
#   ('Air', '^', '0,7239'),
#   ('France', '^', '0,9976'),
#   ('#FAIL', '#', '0,8879')],
#  [('Ser\xc3\xa1', '^', '0,4293'),
#   ('AIR', '^', '0,5216'),
#   ('FRANCE', '^', '0,9986'),
#   ('PHOTO', 'N', '0,9793'),
#   ('Netherlands', '^', '0,9948'),
#   ('Bolivian', '^', '0,9496'),
#   ('TV', 'N', '0,7282'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9978'),
#   ('plane', 'N', '0,7911'),
#   ('crash', 'N', '0,8865')],
#  [('Quando', '^', '0,5595'),
#   ('nao', '^', '0,4667'),
#   ('os', 'N', '0,8247'),
#   ('factos', 'N', '0,3668'),
#   ('d\xc3\xa1', 'N', '0,3183'),
#   ('nisto', 'N', '0,4661'),
#   ('BolivianPolisandDutch', '^', '0,3528'),
#   ('newsfall', '^', '0,8899'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Kitchen', '^', '0,7882'),
#   ('galley', 'N', '0,8897'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,7655'),
#   ('Atlantic', '^', '0,8718')],
#  [('Newscast', 'N', '0,9860'),
#   ('pictures', 'N', '0,9513'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,8906'),
#   ('#CredibilityFail', '#', '0,9801')],
#  [('False', 'A', '0,9028'),
#   ('Report', 'N', '0,9823'),
#   ('Re', 'N', '0,7682'),
#   ('Air', 'N', '0,7490'),
#   ('France', '^', '0,9031'),
#   ('Photos', 'N', '0,9752')],
#  [('Amazing', 'A', '0,8850'),
#   ('ppl', 'N', '0,9895'),
#   ('pics', 'N', '0,9823'),
#   ('AIR', '^', '0,5216'),
#   ('FRANCE', '^', '0,9986'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,8630'),
#   ('TV', 'N', '0,9911'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9978'),
#   ('crash', 'N', '0,9497')],
#  [('retarded', 'A', '0,9985'),
#   ('Media', 'N', '0,5340'),
#   ('scene', 'N', '0,9927'),
#   ('Lost', 'A', '0,5069'),
#   ('real', 'A', '0,9912'),
#   ('photos', 'N', '0,9993'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,9380')],
#  [('New', 'A', '0,9111'),
#   ('Blog', 'N', '0,9088'),
#   ('Post', 'N', '0,9731'),
#   ('Air', '^', '0,6981'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7631'),
#   ('Photographs', 'N', '0,9931')],
#  [('BLOG', 'N', '0,9309'),
#   ('spectabilis', 'N', '0,3334'),
#   ('kate', '^', '0,9402'),
#   ('gosselin', '^', '0,9444'),
#   ('bikini', 'N', '0,7948'),
#   ('pittsburghtrue', '^', '0,2481'),
#   ('bloodair', '^', '0,6732'),
#   ('france', '^', '0,9964'),
#   ('terroristvict', 'N', '0,3204')],
#  [('Final', 'A', '0,9264'),
#   ('Destination', 'N', '0,9996'),
#   ('trending', 'A', '0,4416'),
#   ('topic-A', 'N', '0,8872'),
#   ('women', 'N', '0,9562'),
#   ('flight', 'N', '0,9952'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9987'),
#   ('flight', 'N', '0,9348'),
#   ('car', 'N', '0,9980'),
#   ('crash', 'N', '0,6392')],
#  [('Agora', '^', '0,7837'),
#   ('que', '^', '0,5848'),
#   ('j\xc3\xa1', '^', '0,7300'),
#   ('Au\xc3\xaa', '^', '0,4696'),
#   ('Air', '^', '0,5149'),
#   ('France', '^', '0,9988'),
#   ('minha', '^', '0,4416'),
#   ('homenagem', '^', '0,5959')],
#  [('Air', '^', '0,7902'),
#   ('France', '^', '0,9989'),
#   ('Crash', 'N', '0,7691'),
#   ('pic', 'N', '0,8848'),
#   ('01', '$', '0,9946'),
#   ('gaping', 'A', '0,8956'),
#   ('hole', 'N', '0,9991'),
#   ('fuselage', 'N', '0,9967'),
#   ('tailp', 'N', '0,8750')],
#  [('Image', 'N', '0,9736'),
#   ('Air', '^', '0,7780'),
#   ('France', '^', '0,9988'),
#   ('picture', 'N', '0,9466'),
#   ('hoax', 'N', '0,9874'),
#   ('#airfrance', '#', '0,5439'),
#   ('#lost', '#', '0,9734'),
#   ('#hoax', '#', '0,9829')],
#  [('BNR', '^', '0,7383'),
#   ('Newsradio', '^', '0,9926'),
#   ('Netherlands', '^', '0,9966'),
#   ('Bolivian', '^', '0,9496'),
#   ('TV', 'N', '0,7282'),
#   ('fall', 'N', '0,5382'),
#   ('fake', 'A', '0,9980'),
#   ('pictures', 'N', '0,9994'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9985'),
#   ('447', '$', '0,9551'),
#   ('crash', 'N', '0,9799')],
#  [('Pictures', 'N', '0,9240'),
#   ('Air', '^', '0,5383'),
#   ('France', '^', '0,9993'),
#   ('Plane', '^', '0,8076'),
#   ('Crash', 'N', '0,5706')],
#  [('Photo', 'N', '0,9611'),
#   ('Air', '^', '0,7414'),
#   ('France', '^', '0,9983'),
#   ('flt', 'N', '0,6527'),
#   ('447', '$', '0,9594'),
#   ('projected', 'A', '0,8467'),
#   ('flight', 'N', '0,9922'),
#   ('plan', 'N', '0,9600')],
#  [('AIR', '^', '0,6636'),
#   ('FRANCE', '^', '0,9987'),
#   ('PHOTO', 'N', '0,9335'),
#   ('HOAX', 'N', '0,9061')],
#  [('EPIC', 'N', '0,6434'),
#   ('#FAIL', '#', '0,5049'),
#   ('del', '^', '0,3088'),
#   ('a\xc3\xb1o', '^', '0,4345'),
#   ('Supuestas', '^', '0,5935'),
#   ('fotos', '^', '0,6584'),
#   ('accidnte', '^', '0,3318'),
#   ('del', '^', '0,8407'),
#   ('avion', '^', '0,9387'),
#   ('AirFrance', '^', '0,8225'),
#   ('sn', '^', '0,4904'),
#   ('LOST', 'A', '0,4970')],
#  [('Internet', 'N', '0,8700'),
#   ('Hoax', 'N', '0,9770'),
#   ('Air', '^', '0,7032'),
#   ('France', '^', '0,9985'),
#   ('pictures', 'N', '0,9932'),
#   ('plane', 'N', '0,9208'),
#   ('mid', 'A', '0,9675'),
#   ('air', 'N', '0,9970'),
#   ('way', 'N', '0,9965')],
#  [('Bolivian', '^', '0,8697'),
#   ('TV', 'N', '0,7531'),
#   ('same', 'A', '0,9927'),
#   ('pictures', 'N', '0,9992'),
#   ('Air', '^', '0,7310'),
#   ('France', '^', '0,9964')],
#  [('New', 'A', '0,9111'),
#   ('Blog', 'N', '0,9088'),
#   ('Post', 'N', '0,9731'),
#   ('Air', '^', '0,6981'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7631'),
#   ('Photographs', 'N', '0,9929'),
#   ('Link', 'N', '0,6101')],
#  [('UPDATE', 'N', '0,9448'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('UPDATE', 'N', '0,9482'),
#   ('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9989'),
#   ('Flight', 'N', '0,9143'),
#   ('447', '$', '0,9765'),
#   ('Photo', 'N', '0,9252'),
#   ('Hoax', 'N', '0,9437'),
#   ('Source', 'N', '0,9304'),
#   ('Failure', 'N', '0,9402')],
#  [('Military', 'A', '0,6111'),
#   ('ships', 'N', '0,9915'),
#   ('signal', 'N', '0,9220'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9995'),
#   ('Airbus', '^', '0,9740'),
#   ('black', 'A', '0,9284'),
#   ('boxes', 'N', '0,9987'),
#   ('Times', 'N', '0,7943'),
#   ('Online', 'N', '0,4602'),
#   ('Washington', '^', '0,9885')],
#  [('Bolivian', '^', '0,9396'),
#   ('newscast', 'N', '0,9898'),
#   ('footage', 'N', '0,9886'),
#   ('LOST', 'A', '0,7014'),
#   ('TV', 'N', '0,9144'),
#   ('show', 'N', '0,9848'),
#   ('photo', 'N', '0,9797'),
#   ('evidence', 'N', '0,9784'),
#   ('Air', '^', '0,9132'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9195'),
#   ('447', '$', '0,9704'),
#   ('crash', 'N', '0,9321')],
#  [('Bolivian', '^', '0,9668'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,7673'),
#   ('photo', 'N', '0,9888'),
#   ('hoax', 'N', '0,9893')],
#  [('\xc2\xbfSer\xc3\xa1', '^', '0,4837'),
#   ('cierta', '^', '0,7716'),
#   ('esta', '^', '0,7855'),
#   ('imagen', '^', '0,6034'),
#   ('previa', '^', '0,5241'),
#   ('la', '^', '0,6777'),
#   ('ca\xc3\xadda', '^', '0,8057'),
#   ('del', '^', '0,8463'),
#   ('vuelo', '^', '0,6992'),
#   ('447', '$', '0,9316'),
#   ('Air', '^', '0,6753'),
#   ('France', '^', '0,9990')],
#  [('Bolivian', '^', '0,9447'),
#   ('Polish', '^', '0,4325'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9903')],
#  [('bull', 'N', '0,9725'),
#   ('Passenger', '^', '0,5896'),
#   ('Photos', 'N', '0,9848'),
#   ('Air', '^', '0,7574'),
#   ('France', '^', '0,9994'),
#   ('Plane', '^', '0,8368')],
#  [('airfrance', '^', '0,7709'), ('pics', 'N', '0,9298')],
#  [('Bolivian', '^', '0,8764'),
#   ('TV', 'N', '0,7419'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9988'),
#   ('crash', 'N', '0,7207'),
#   ('hoax', 'N', '0,9623'),
#   ('pictures', 'N', '0,9513')],
#  [('Paris', '^', '0,9966'),
#   ('Air', '^', '0,6224'),
#   ('France', '^', '0,9972'),
#   ('passenger', 'N', '0,9661'),
#   ('locator', 'N', '0,9776'),
#   ('card', 'N', '0,9495'),
#   ('H1N1', '$', '0,3857'),
#   ('flu', 'N', '0,9699')],
#  [('citizen', 'N', '0,9493'),
#   ('media', 'N', '0,9812'),
#   ('Bolivian', '^', '0,7616'),
#   ('TV', '^', '0,5014'),
#   ('news', 'N', '0,8353'),
#   ('photos', 'N', '0,9938'),
#   ('Air', '^', '0,9558'),
#   ('France', '^', '0,9988'),
#   ('disaster', 'N', '0,9800'),
#   ("TV's", 'N', '0,7215')],
#  [('Fake', 'A', '0,9831'),
#   ('AF447', '^', '0,3825'),
#   ('photos', 'N', '0,9556'),
#   ('Air', '^', '0,7989'),
#   ('France', '^', '0,9991'),
#   ('Flight', 'N', '0,9195'),
#   ('447', '$', '0,9873'),
#   ('Dutch', 'A', '0,5689'),
#   ('radio', 'N', '0,9973'),
#   ('station', 'N', '0,9987'),
#   ('images', 'N', '0,9942'),
#   ('real', 'A', '0,9353'),
#   ('post', 'N', '0,6902')],
#  [('Bolivian', '^', '0,9908'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('TV', 'N', '0,9035'),
#   ('e', 'N', '0,4363'),
#   ('queda', '^', '0,6155'),
#   ('Air', '^', '0,8949'),
#   ('France', '^', '0,9991'),
#   ('#epicfail', '#', '0,9646')],
#  [('pictures', 'N', '0,9961'),
#   ('Air', '^', '0,7198'),
#   ('France', '^', '0,9987'),
#   ('flight', 'N', '0,9869'),
#   ('fake', 'A', '0,9956'),
#   ('#airfrance', '#', '0,9148')],
#  [('News', 'N', '0,5745'),
#   ('Outlets', 'N', '0,9900'),
#   ('Shocking', 'A', '0,9709'),
#   ('Air', '^', '0,8159'),
#   ('France', '^', '0,9988'),
#   ('Crash', 'N', '0,7106'),
#   ('Pictures', 'N', '0,9732'),
#   ('Stills', 'N', '0,6595'),
#   ('\xc3\xa2\xef\xbf\xbd\xef\xbf\xbdLost\xc3\xa2\xef\xbf\xbd\xef\xbf\xbd',
#    '^',
#    '0,7969')],
#  [('Air', '^', '0,7006'),
#   ('France', '^', '0,9994'),
#   ('Flight', 'N', '0,9110'),
#   ('447', '$', '0,9797'),
#   ('BreakingNews', '^', '0,8205'),
#   ('Bolivian', '^', '0,9967'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9893')],
#  [('Air', '^', '0,6493'),
#   ('France', '^', '0,9987'),
#   ('Crash', 'N', '0,9032'),
#   ('2', '$', '0,8743'),
#   ('photos', 'N', '0,9964'),
#   ('Collision', 'N', '0,7634'),
#   ('Death', 'N', '0,9681')],
#  [('Homer', '^', '0,9943'),
#   ('Bolivian', '^', '0,9551'),
#   ('Polish', '^', '0,4421'),
#   ('Dutch', 'A', '0,5562'),
#   ('news', 'N', '0,9969'),
#   ('outlets', 'N', '0,9890'),
#   ('Air', '^', '0,8641'),
#   ('France', '^', '0,9989'),
#   ('photo', 'N', '0,9834'),
#   ('hoax', 'N', '0,9716')],
#  [('447', '$', '0,9568'),
#   ('Professional', 'A', '0,8589'),
#   ('photog', 'N', '0,9987'),
#   ('ill-fated', 'A', '0,9966'),
#   ('#AirFrance', '^', '0,8715'),
#   ('flight', 'N', '0,9466'),
# ...
#   ('Palin', '^', '0,9846'),
#   ('Todd', '^', '0,9990'),
#   ('Sarah', '^', '0,9952'),
#   ('#Palin', '#', '0,4557'),
#   ('divorce', 'N', '0,7724')],
#  [('Todd', '^', '0,9955'),
#   ('Sarah', '^', '0,9927'),
#   ('2', '$', '0,6240'),
#   ('#Palindivorce', '#', '0,4687')],
#  [('New', 'A', '0,9840'),
#   ('#1', '$', '0,9314'),
#   ('#2', '$', '0,8164'),
#   ('Todd', '^', '0,9986'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,9171')],
#  [('Sarah', '^', '0,9973'),
#   ('Palin', '^', '0,9684'),
#   ('Twitterverse', 'N', '0,7865'),
#   ('Internets', 'N', '0,4968'),
#   ('coverage', 'N', '0,9975'),
#   ('divorce', 'N', '0,9989')],
#  [('Palin', '^', '0,9001'),
#   ('Addresses', 'N', '0,7287'),
#   ('Divorce', 'N', '0,9807'),
#   ('Rumors', 'N', '0,9982'),
#   ('Question', 'N', '0,9347')],
#  [('Family', 'N', '0,6667'),
#   ('values', 'N', '0,9925'),
#   ('#sarah', '#', '0,9386'),
#   ('palin', '^', '0,5109'),
#   ('divorce', 'N', '0,9968')],
#  [('Love', 'N', '0,8236'),
#   ('grand', 'A', '0,9637'),
#   ('divorce', 'N', '0,9881'),
#   ('hundred', '$', '0,8225'),
#   ('grand', 'A', '0,8913')],
#  [('Sarah', '^', '0,9823'),
#   ('Palin', '^', '0,9484'),
#   ('husband', 'N', '0,9990'),
#   ('Todd', '^', '0,9903'),
#   ('former', 'A', '0,8017'),
#   ('first', 'A', '0,8607'),
#   ('dude', 'N', '0,9959'),
#   ('two', '$', '0,9660'),
#   ('different', 'A', '0,9954'),
#   ('ways', 'N', '0,9991')],
#  [('Spokeswoman', 'N', '0,9101'),
#   ('Sarah', '^', '0,9958'),
#   ('Todd', '^', '0,9990'),
#   ('Palin', '^', '0,9895'),
#   ('Divorce', 'N', '0,7650'),
#   ('Rumors', 'N', '0,9983')],
#  [('Traditional', '^', '0,4192'),
#   ('Family', '^', '0,7846'),
#   ('Values', '^', '0,5429'),
#   ('Sarah', '^', '0,9905'),
#   ('Todd', '^', '0,9990'),
#   ('Palin', '^', '0,9744'),
#   ('Divorce', 'N', '0,8280')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('Divorce', 'N', '0,7246'),
#   ('Rumor', 'N', '0,9822'),
#   ('Surfaces', 'N', '0,9948'),
#   ('Shot', 'N', '0,6440'),
#   ('Down', 'N', '0,6708'),
#   ('Rumors', 'N', '0,9932'),
#   ('Todd', '^', '0,9985'),
#   ('Palin-Sarah', '^', '0,9851'),
#   ('Palin', '^', '0,9722'),
#   ('divorce', 'N', '0,9388'),
#   ('lot', 'N', '0,9842')],
#  [('Plain', '^', '0,5347'),
#   ('divorce', 'N', '0,9512'),
#   ('rumor', 'N', '0,9980'),
#   ('Palin', '^', '0,9752'),
#   ('run', 'N', '0,8717'),
#   ('White', '^', '0,6256'),
#   ('House', '^', '0,9047'),
#   ('circus', 'N', '0,9907')],
#  [('Re', 'N', '0,6635'),
#   ('Sarah', '^', '0,9946'),
#   ('Palin', '^', '0,9522'),
#   ('secret', 'A', '0,9081'),
#   ('plans', 'N', '0,9938'),
#   ('divorce', 'N', '0,9836')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('divorce', 'N', '0,9560'),
#   ('reports', 'N', '0,9896'),
#   ('untrue', 'A', '0,9996'),
#   ('ex-governor', 'N', '0,8376')],
#  [('notizie', 'N', '0,2768'),
#   ('fresche', 'N', '0,3629'),
#   ('BREAKING', 'N', '0,6771'),
#   ('Todd', '^', '0,9976'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,6842')],
#  [('Todd', '^', '0,9960'),
#   ('Palin', '^', '0,9950'),
#   ('former', 'A', '0,8941'),
#   ('Alaska', '^', '0,9909'),
#   ('governor', '^', '0,4964'),
#   ('Sarah', '^', '0,9990'),
#   ('Palin', '^', '0,9815'),
#   ('divorce', 'N', '0,9150')],
#  [('Top', 'A', '0,9479'),
#   ('ten', '$', '0,9133'),
#   ('reasons', 'N', '0,9828'),
#   ('possible', 'A', '0,9951'),
#   ('Palin', '^', '0,9279'),
#   ('divorce', 'N', '0,9810'),
#   ('10', '$', '0,9859'),
#   ('guys', 'N', '0,9436'),
#   ('media', 'N', '0,9487'),
#   ('stuff', 'N', '0,9695'),
#   ('#PalinDivorceReasons', '#', '0,9728')],
#  [('Sarah', '^', '0,9944'),
#   ('Palin', '^', '0,9784'),
#   ('divorce', 'N', '0,9683'),
#   ('Plausible', 'A', '0,8207'),
#   ('sure', 'A', '0,9617'),
#   ('family', 'N', '0,9977'),
#   ('outside', 'N', '0,3785'),
#   ('marriage', 'N', '0,9987'),
#   ('#fb', '#', '0,9745')],
#  [('divorce', 'N', '0,9973'),
#   ("Palin's", 'Z', '0,8037'),
#   ('life', 'N', '0,9878'),
#   ('awesome', 'A', '0,9835')],
#  [('Last', 'A', '0,9945'),
#   ('night', 'N', '0,9923'),
#   ('Sarah', '^', '0,9974'),
#   ('Palin', '^', '0,9879'),
#   ('friend', 'N', '0,9924'),
#   ('guilty', 'A', '0,9743'),
#   ('juicy', 'A', '0,9767'),
#   ('divorce', 'N', '0,9963'),
#   ('rumors', 'N', '0,9942'),
#   ('conscience', 'N', '0,9995'),
#   ('tough', 'A', '0,9878')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9481'),
#   ('Divorce', 'N', '0,6920'),
#   ('Husband', 'N', '0,9924')],
#  [('Todd', '^', '0,9952'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8670')],
#  [('true', 'A', '0,9886'),
#   ('AlaskaReport', '^', '0,4689'),
#   ('morning', 'N', '0,9948'),
#   ('Todd', '^', '0,9988'),
#   ('Palin', '^', '0,9950'),
#   ('former', 'A', '0,8941'),
#   ('Alaska', '^', '0,9909'),
#   ('governor', '^', '0,4964'),
#   ('Sarah', '^', '0,9990'),
#   ('Palin', '^', '0,9815'),
#   ('divorce', 'N', '0,9213')],
#  [('AlaskaReport', '^', '0,2332'),
#   ('Todd', '^', '0,9961'),
#   ('Palin', '^', '0,9950'),
#   ('former', 'A', '0,8941'),
#   ('Alaska', '^', '0,9909'),
#   ('governor', '^', '0,4964'),
#   ('Sarah', '^', '0,9990'),
#   ('Palin', '^', '0,9815'),
#   ('divorce', 'N', '0,9180')],
#  [('Sarah', '^', '0,9948'),
#   ('Palin', '^', '0,9694'),
#   ('Facebook', '^', '0,9872'),
#   ('unsourced', 'A', '0,4297'),
#   ('divorce', 'N', '0,9942'),
#   ('rumors', 'N', '0,9831')],
#  [('CNN', '^', '0,9375'),
#   ('stringer', '^', '0,9266'),
#   ('Dennis', '^', '0,9996'),
#   ('Zaki', '^', '0,9997'),
#   ('SOURCE', 'N', '0,9659'),
#   ('Palin', '^', '0,9858'),
#   ('divorce', 'N', '0,9739'),
#   ('email', 'N', '0,8060'),
#   ('CNN', 'N', '0,7087'),
#   ('#palin', '#', '0,9786'),
#   ('#sgp', '#', '0,9965'),
#   ('#tcot', '#', '0,9976'),
#   ('#conservative', '#', '0,9890'),
#   ('#ttparty', '#', '0,9955')],
#  [('Todd', '^', '0,9955'),
#   ('Sarah', '^', '0,9974'),
#   ('Palin', '^', '0,9528'),
#   ('divorce', 'N', '0,9324'),
#   ('#celebrities', '#', '0,8585'),
#   ('#sarahpalin', '#', '0,9971'),
#   ('#alaska', '#', '0,9908'),
#   ('#johnmccain', '#', '0,9888')],
#  [('query', 'N', '0,9980'),
#   ('sarah', '^', '0,9700'),
#   ('palin', '^', '0,8160'),
#   ('divorce', 'N', '0,9660'),
#   ('google', '^', '0,9273'),
#   ('highlights', 'N', '0,5986'),
#   ('word', 'N', '0,9762'),
#   ('dinosaur', 'N', '0,9958'),
#   ('results', 'N', '0,9993'),
#   ('2', '$', '0,6109')],
#  [('New', 'A', '0,9111'),
#   ('Blog', 'N', '0,9088'),
#   ('Post', 'N', '0,9731'),
#   ('Sarah', '^', '0,9857'),
#   ('Todd', '^', '0,9985'),
#   ('Palin', '^', '0,9914'),
#   ('Divorce', 'N', '0,9919'),
#   ('Divorce', 'N', '0,9824'),
#   ('Gawker', '^', '0,4289')],
#  [('Palin', '^', '0,9664'),
#   ('divorce', 'N', '0,9380'),
#   ('rumor', 'N', '0,9922'),
#   ('EPIC', 'A', '0,3539'),
#   ('LULZ', '^', '0,4523'),
#   ('MACROS', 'N', '0,5420')],
#  [('Alaska', '^', '0,9984'),
#   ('Report', 'N', '0,8605'),
#   ('story', 'N', '0,9996'),
#   ('CBS', '^', '0,7739'),
#   ('Palin', '^', '0,8877'),
#   ('Spokespeople', 'N', '0,6219'),
#   ('Divorce', 'N', '0,8676'),
#   ('Rumor', 'N', '0,9954')],
#  [('Palins', '^', '0,9373'),
#   ('Sarah', '^', '0,9968'),
#   ('Palin', '^', '0,9644'),
#   ('Montana', '^', '0,9814'),
#   ('shit', 'N', '0,9968')],
#  [('Sarah/Todd', '^', '0,9285'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8931'),
#   ('bulldog/lipstick', 'N', '0,9670'),
#   ('reference', 'N', '0,9635')],
#  [('Todd', '^', '0,9978'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8670'),
#   ('#republicans', '#', '0,8617'),
#   ('family', 'N', '0,8641'),
#   ('values', 'N', '0,9911'),
#   ('hypocrites', 'N', '0,9669')],
#  [('Todd', '^', '0,9955'),
#   ('Sarah', '^', '0,9974'),
#   ('Palin', '^', '0,9528'),
#   ('divorce', 'N', '0,8225'),
#   ('Affairs', 'N', '0,8044'),
#   ('sides', 'N', '0,9977')],
#  [('name', 'N', '0,9995'),
#   ('sarah', '^', '0,9700'),
#   ('palin', '^', '0,8457'),
#   ('mix', 'N', '0,9502'),
#   ('hard', 'A', '0,8140')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9866'),
#   ('Divorce', 'N', '0,8705'),
#   ('Rumors', 'N', '0,9984'),
#   ('Sarah', '^', '0,9942'),
#   ('Palin', '^', '0,9871'),
#   ('rumors', 'N', '0,8466'),
#   ('husband', 'N', '0,9965'),
#   ('Todd', '^', '0,9904'),
#   ('sp', 'N', '0,8930')],
#  [('next', 'A', '0,5984'),
#   ('Dept', '^', '0,5219'),
#   ('Todd', '^', '0,9976'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8698'),
#   ('mutual', 'A', '0,9269'),
#   ('infidelities', 'N', '0,9920')],
#  [('Palin', '^', '0,9703'),
#   ('affair/divorce', 'N', '0,9083'),
#   ('cartoon', 'N', '0,9905'),
#   ('Suggestions', 'N', '0,9877'),
#   ('Anyone', 'N', '0,9673'),
#   ('moose', 'N', '0,9383'),
#   ('wink', 'N', '0,5626'),
#   ('ubetcha', '^', '0,3567')],
#  [('Todd', '^', '0,9955'),
#   ('Sarah', '^', '0,9974'),
#   ('Palin', '^', '0,9528'),
#   ('divorce', 'N', '0,8679')],
#  [('#tcot', '#', '0,8904'),
#   ('#amspec', '#', '0,9863'),
#   ('Palin', '^', '0,8548'),
#   ('Divorce', 'N', '0,7524'),
#   ('Gossip', 'N', '0,9496'),
#   ('False', 'A', '0,9838')],
#  [('BREAKING', 'N', '0,6619'),
#   ('Todd', '^', '0,9976'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8496')],
#  [('sarah', '^', '0,9625'),
#   ('palin', '^', '0,8129'),
#   ('divorce', 'N', '0,9469'),
#   ('no', 'N', '0,5985'),
#   ('1', '$', '0,9974'),
#   ('search', 'N', '0,9773'),
#   ('term', 'N', '0,9875'),
#   ('google', '^', '0,9555'),
#   ('staff', 'N', '0,9985'),
#   ('bull', 'N', '0,9849')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9577'),
#   ('Divorce', 'N', '0,9840'),
#   ('Oddsmaker', '^', '0,9305'),
#   ('weekend', 'N', '0,9965'),
#   ('rumors', 'N', '0,8726')],
#  [("Palin's", 'Z', '0,7629'),
#   ('lawyer', 'N', '0,9754'),
#   ('divorce', 'N', '0,9877'),
#   ('blogger', 'N', '0,5014'),
#   ('libel', 'N', '0,7770'),
#   ('suit', 'N', '0,9940'),
#   ('option', 'N', '0,9993'),
#   ('summons', 'N', '0,9921')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('Divorce', 'N', '0,7246'),
#   ('Rumor', 'N', '0,9689'),
#   ('Facebook', '^', '0,9956')],
#  [('Sarah', '^', '0,9784'),
#   ('#Palin', '^', '0,5550'),
#   ('divorce', 'N', '0,9985')],
#  [('New', 'A', '0,9703'),
#   ('top', 'A', '0,7510'),
#   ('search', 'N', '0,9884'),
#   ('terms', 'N', '0,9865'),
#   ('#5', '#', '0,4730'),
#   ('sarah', '^', '0,9209'),
#   ('palin', '^', '0,8160'),
#   ('divorce', 'N', '0,9615'),
#   ('#6', '#', '0,5118'),
#   ('appaloosa', '^', '0,9325'),
#   ('movie', 'N', '0,9886')],
#  [('first', 'A', '0,8435'),
#   ('@davewinerAlaskaReport', 'N', '0,3322'),
#   ('Todd', '^', '0,9976'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,9180'),
#   ('Affairs', 'N', '0,8615'),
#   ('sides', 'N', '0,9988')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9880'),
#   ('husband', 'N', '0,9690'),
#   ('divorce', 'N', '0,9817'),
#   ('Sources', 'N', '0,8796'),
#   ('extramarital', 'A', '0,9952'),
#   ('affairs', 'N', '0,9990'),
#   ('sides', 'N', '0,9987'),
#   ("Sarah's", 'Z', '0,8874'),
#   ('denials', 'N', '0,9932')],
#  [('affairs', 'N', '0,9877'),
#   ('Sarah', '^', '0,9857'),
#   ('Todd', '^', '0,9985'),
#   ('Palin', '^', '0,9914'),
#   ('Divorce', 'N', '0,9919'),
#   ('#fb', '#', '0,9849')],
#  [('Sarah', '^', '0,9959'),
#   ('Palin', '^', '0,9719'),
#   ('Divorce', 'N', '0,9497'),
#   ('Rumors', 'N', '0,9956'),
#   ('reps', 'N', '0,9993')],
#  [('Palin', '^', '0,9253'),
#   ('camp', 'N', '0,6114'),
#   ('divorce', 'N', '0,9590'),
#   ('rumors', 'N', '0,9942'),
#   ('time', 'N', '0,9307'),
#   ('Sanford', '^', '0,9982'),
#   ('denials', 'N', '0,9664')],
#  [('Source', 'N', '0,9859'),
#   ('Palin', '^', '0,9891'),
#   ('divorce', 'N', '0,8751'),
#   ('story', 'N', '0,9997'),
#   ('Conservatives4Palin', '^', '0,2534'),
#   ('ridiculous', 'A', '0,9972'),
#   ('rumors', 'N', '0,9968')],
#  [('Todd', '^', '0,9978'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8437'),
#   ('#familyvalues', '#', '0,9182'),
#   ('happier', 'A', '0,9818')],
#  [('ArkieIcon_lockRT', '^', '0,7741'),
#   ('OTHER', 'A', '0,9274'),
#   ('SHOE', 'N', '0,9792'),
#   ('DROPS', 'N', '0,6531'),
#   ('Todd', '^', '0,9977'),
#   ('Sarah', '^', '0,9975'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,9360')],
#  [('great', 'A', '0,9900'),
#   ('more', 'A', '0,6450'),
#   ('Palin', '^', '0,8065'),
#   ('gossip', 'N', '0,7412'),
#   ('sure', 'A', '0,5532'),
#   ('palin', '^', '0,6438'),
#   ('divorce', 'N', '0,9666')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('Divorce', 'N', '0,7246'),
#   ('Rumor', 'N', '0,9689'),
#   ('Facebook', '^', '0,9969')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('divorce', 'N', '0,9657'),
#   ('Plausible', 'A', '0,8207'),
#   ('sure', 'A', '0,9617'),
#   ('family', 'N', '0,9977'),
#   ('outside', 'N', '0,3785'),
#   ('marriage', 'N', '0,9975'),
#   ('#fb', '#', '0,9720')],
#  [('Re', 'N', '0,7745'),
#   ('Britney', '^', '0,9895'),
#   ('Spears', '^', '0,9778'),
#   ('WOMANIZER', '^', '0,9213'),
#   ('Palin', '^', '0,5735'),
#   ('SNL', '^', '0,7000'),
#   ('Madonna', '^', '0,9872'),
#   ('Divorce', 'N', '0,9270')],
#  [('Sarah', '^', '0,9948'),
#   ('Palin', '^', '0,9784'),
#   ('Divorce', 'N', '0,7553'),
#   ('Rumor', 'N', '0,9706'),
#   ('Facebook', '^', '0,9975')],
#  [('New', 'A', '0,9111'),
#   ('blog', 'N', '0,9846'),
#   ('post', 'N', '0,9622'),
#   ('Sarah', '^', '0,9942'),
#   ('Palin', '^', '0,9868'),
#   ('Divorce', 'N', '0,9910')],
#  [('Sarah', '^', '0,9969'),
#   ('Palin', '^', '0,9650'),
#   ('Pwn', '^', '0,4858'),
#   ('media', 'N', '0,9162'),
#   ('divorce', 'N', '0,9378'),
#   ('rumors', 'N', '0,9959')],
#  [('3rd', 'A', '0,4880'),
#   ('time-pregnancy', 'N', '0,9953'),
#   ('ethics', 'N', '0,9838'),
#   ('divorce-Palin', 'N', '0,6952'),
#   ('journos', 'N', '0,7704'),
#   ('story', 'N', '0,9841'),
#   ('Neverending', '^', '0,7153'),
#   ('Palin', '^', '0,9905'),
#   ('pity', 'N', '0,9224'),
#   ('party', 'N', '0,9679')],
#  [('blog', 'N', '0,9040'),
#   ("Palin's", 'Z', '0,8814'),
#   ('wrong', 'A', '0,9863'),
#   ('skeptical', 'A', '0,9945')],
#  [('lot', 'N', '0,8810'),
#   ('Todd', '^', '0,9985'),
#   ('Sarah', '^', '0,9964'),
#   ('Palin', '^', '0,9484'),
#   ('divorce', 'N', '0,8670')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9777'),
#   ('divorce', 'N', '0,9560'),
#   ('reports', 'N', '0,9896'),
#   ('untrue', 'A', '0,9996'),
#   ('ex-governor', 'N', '0,8376'),
#   ("Alaska's", 'Z', '0,8613'),
#   ('people', 'N', '0,9985'),
#   ('former', 'A', '0,8335'),
#   ('Alaska', '^', '0,9909'),
#   ('governor', 'N', '0,7274')],
#  [('Sarah', '^', '0,9894'),
#   ('Palin', '^', '0,9880'),
#   ('Todd', '^', '0,9986'),
#   ('Palin', '^', '0,9926'),
#   ('Divorce', 'N', '0,5199'),
#   ('Celebrity', 'N', '0,9422'),
#   ('News', 'N', '0,9384')],
#  [('Palin', '^', '0,9593'),
#   ('divorce', 'N', '0,9590'),
#   ('rumors', 'N', '0,9662'),
#   ('Christian', '^', '0,9972'),
#   ('Science', '^', '0,6751'),
#   ('Monitor', 'N', '0,6754')],
#  [('Mudflats', 'N', '0,5313'),
#   ('Palin', '^', '0,9441'),
#   ('Divorce', 'N', '0,8491'),
#   ('Ring', 'N', '0,7613'),
#   ('Bottom', 'N', '0,7306'),
#   ('Lake', '^', '0,8544'),
#   ('Guns', 'N', '0,9321')],
#  [('AKMuckraker', '^', '0,5599'),
#   ('Palins', '^', '0,9297'),
#   ('Divorce', 'N', '0,7848'),
#   ('blogosphere', 'N', '0,9242'),
#   ('Alaska', '^', '0,9985'),
#   ('fire', 'N', '0,6780'),
#   ('morning', 'N', '0,9967'),
#   ('explosive', 'A', '0,9930'),
#   ('new', 'A', '0,9889'),
#   ('allegation', 'N', '0,9996')],
#  [('Sarah', '^', '0,9945'),
#   ('Palin', '^', '0,9784'),
#   ('Divorce', 'N', '0,7553'),
#   ('Rumor', 'N', '0,9706'),
#   ('Facebook', '^', '0,9965')],
#  [('Palin', '^', '0,7891'),
#   ('divorce', 'N', '0,6175'),
#   ('mutual', 'A', '0,9269'),
#   ('infidelities', 'N', '0,9747')],
#  [('Sarah', '^', '0,9950'),
#   ('Palin', '^', '0,9784'),
#   ('Divorce', 'N', '0,7553'),
#   ('Rumor', 'N', '0,9706'),
#   ('Facebook', '^', '0,9975')],
#  [('Divorce', 'N', '0,9121')],
#  [('Palin', '^', '0,8524'),
#   ('divorce', 'N', '0,8751'),
#   ('story', 'N', '0,9989'),
#   ('internet', 'N', '0,6006'),
#   ('rumor', 'N', '0,9885')],
#  [('Alaska', '^', '0,9978'),
#   ('Palin', '^', '0,9096'),
#   ('life', 'N', '0,9924'),
#   ('divorce', 'N', '0,9930'),
#   ('new', 'A', '0,9899'),
#   ('black', 'A', '0,6183')],
#  [('Dems', 'N', '0,5485'),
#   ('afraid', 'A', '0,9880'),
#   ('amusing', 'A', '0,9831'),
#   ('Sarah', '^', '0,9944'),
#   ('Palin', '^', '0,9820')],
#  [('Alex', '^', '0,9988'),
#   ('party', 'N', '0,9970'),
#   ('Palin', '^', '0,9069'),
#   ('divorce', 'N', '0,9947'),
#   ('2', '$', '0,9284'),
#   ('people', 'N', '0,9977'),
#   ('Tel', '^', '0,9250'),
#   ('Aviv', '^', '0,9650'),
#   ('good', 'A', '0,9910'),
#   ('talk', 'N', '0,9876')],
#  ...]

# %%
tags_meaning={
  "N":"common noun",
  "O":"pronoun (personal/WH; not possessive)",  
  "^":"proper noun",  
  "S":"nominal + possessive(lady's)",
  "Z":"proper noun + possessive (Palin's, Alaska's)",  

  "V":"verb incl. copula, auxiliaries",
  "A":"adjective",
  "R":"adverb",
  "!":"interjection",

  "D":"determiner",
  "P":"pre- or postposition, or subordinating conjunction",
  "&":"coordinating conjunction",
  "T":"verb particle",
  "X":"existential _there_, predeterminers",

  "#":"hashtag (indicates topic/category for tweet)", 
  "@":"at-mention (indicates another user as a recipient of a tweet)",
  "~":"discourse marker, indications of continuation of a message across multiple tweets",
  "U":"URL or email address",
  "E":"emoticon",
 
  "$":"numeral",
  ",":"punctuation",
  "G":"other abbreviations, foreign words, possessive endings, symbols, garbage",
 
  "L":"nominal + verbal (e.g. _i'm_), verbal + nominal (_let's_, _lemme_)",
  "M":"proper noun + verbal",
  "Y":" 'X' + verbal"
}

# %%
tags_to_keep = [ 'N','^','S','Z','A','#','$']
